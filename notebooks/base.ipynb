# %% [markdown]
# <a href="https://colab.research.google.com/github/deckinhow/repositorio_grupo4/blob/main/notebooks/base.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/deckinhow/repositorio_grupo4.git
# Out:
# Cloning into 'repositorio_grupo4'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 17 (delta 6), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (17/17), 5.52 KiB | 1.84 MiB/s, done.
# Resolving deltas: 100% (6/6), done.

# %%
# %cd repositorio_grupo4/
# Out:
# /content/repositorio_grupo4
