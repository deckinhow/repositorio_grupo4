# %% [markdown]
# <a href="https://colab.research.google.com/github/deckinhow/repositorio_grupo4/blob/main/00testes_derick.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Isso é um teste!')
# Out:
# Isso é um teste!

# %%
print('Outro teste hihi')
print('Explicarei depois pra quem não entendeu nada')
# Out:
# Outro teste hihi
# Explicarei depois pra quem não entendeu nada
