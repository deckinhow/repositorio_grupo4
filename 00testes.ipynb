# %% [markdown]
# <a href="https://colab.research.google.com/github/deckinhow/repositorio_grupo4/blob/main/00testes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Isso é um teste!')
# Out:
# Isso é um teste!

# %%
print('Outro teste hihi')
print('Explicarei depois pra quem não entendeu nada')
for i in range(0,5):
  print('teste')
# Out:
# Outro teste hihi
# Explicarei depois pra quem não entendeu nada
# teste
# teste
# teste
# teste
# teste

# %% [markdown]
# Este notebook serve pra se aventurar no mundo mágico do collab. Quando abrirem esse notebook, voces terao uma copia dele. Se voces não alterarem o nome do ipynb, ele sobreescreverá o que já está salvo no github, mas se mudarem o nome do arquivo (ex: 00testes_fulano) voces criarao um novo arquivo ipynb no github. Tem um arquivo com meu nome lá e se voces verem nao tem quase nada, porque eu estou sobreescrevendo em cima do original. Em (arquivo -> salvar uma copia no github) voces conseguem salvar a alteracao de voces no repositorio
